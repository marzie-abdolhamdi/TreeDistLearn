# %%
import math
from collections import Counter, defaultdict
import numpy as np
import matplotlib.pyplot as plt
import dendropy

def canon_label(x: str) -> str:
    return x.strip().strip("'\"").replace(" ", "_")

def relabel_tree_inplace(tree):
    for nd in tree.leaf_node_iter():
        if nd.taxon is not None and nd.taxon.label is not None:
            nd.taxon.label = canon_label(nd.taxon.label)

def topology_key_unrooted(tree):
    """
    Returns a canonical tuple key for the unrooted topology using non-trivial splits.
    Assumes tree.taxon_namespace is consistent across trees.
    """
    tree.is_rooted = False
    tree.encode_bipartitions()
    full_mask = tree.taxon_namespace.all_taxa_bitmask()
    splits = []
    for b in tree.bipartition_encoding:
        if b.is_trivial():
            continue
        x = b.split_bitmask
        x = min(x, full_mask ^ x)  # canonical orientation
        splits.append(x)
    return tuple(sorted(splits))

def load_treelist(path, schema, taxa):
    trees = dendropy.TreeList.get(
        path=path,
        schema=schema,
        taxon_namespace=taxa,
        preserve_underscores=True,
    )
    for t in trees:
        t.is_rooted = False
        relabel_tree_inplace(t)
    return trees

def topology_mass_from_trees(trees, weighted=False):
    """
    Returns dict: topo_key -> probability mass.
    If weighted=True, uses t.weight when present (MrBayes trprobs).
    """
    counts = defaultdict(float)
    total = 0.0
    for t in trees:
        w = float(t.weight) if (weighted and getattr(t, "weight", None) is not None) else 1.0
        counts[topology_key_unrooted(t)] += w
        total += w
    return {k: v/total for k, v in counts.items()} if total > 0 else {}

# paths
sampled_nexus_path = "results_converge_elbo/run_20260219_001447_ntaxa27/sampled_trees.nex"
trprobs_path = "data/DS1.trprobs"

taxa = dendropy.TaxonNamespace()
sampled = load_treelist(sampled_nexus_path, "nexus", taxa)
mb = load_treelist(trprobs_path, "nexus", taxa)

Q = topology_mass_from_trees(sampled, weighted=False)  # your model
P = topology_mass_from_trees(mb, weighted=True)        # MrBayes

print("Unique topologies (model):", len(Q))
print("Unique topologies (MB):", len(P))

overlap = set(P) & set(Q)
print("Support overlap count:", len(overlap))
print("MB mass on overlap:", sum(P[k] for k in overlap))
print("Model mass on overlap:", sum(Q[k] for k in overlap))
# Out:
# Unique topologies (model): 657
# Unique topologies (MB): 1209
# Support overlap count: 0
# MB mass on overlap: 0
# Model mass on overlap: 0

# %%
# Plot top‑K topology masses (side-by-side)
def topk_items(d, k=20):
    return sorted(d.items(), key=lambda kv: kv[1], reverse=True)[:k]

K = 1000
topP = topk_items(P, K)
topQ = topk_items(Q, K)

# Use ranks 1..K; labels are just rank indices (topology keys are huge)
x = np.arange(1, K+1)

pvals = [v for _, v in topP] + [0.0]*max(0, K-len(topP))
qvals = [v for _, v in topQ] + [0.0]*max(0, K-len(topQ))

plt.figure(figsize=(10,4))
plt.bar(x - 0.2, pvals[:K], width=0.4, label="MrBayes (top-K)")
plt.bar(x + 0.2, qvals[:K], width=0.4, label="Model (top-K)")
plt.xlabel("Topology rank (within each distribution)")
plt.ylabel("Probability mass")
plt.title(f"Top-{K} Topology Masses (Unrooted)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
def rank_curve(d):
    vals = sorted(d.values(), reverse=True)
    ranks = np.arange(1, len(vals)+1)
    return ranks, np.array(vals)

rP, vP = rank_curve(P)
rQ, vQ = rank_curve(Q)

plt.figure(figsize=(6,4))
plt.loglog(rP, vP, label="MrBayes")
plt.loglog(rQ, vQ, label="Model")
plt.xlabel("Rank")
plt.ylabel("Mass")
plt.title("Topology Rank–Mass (log-log)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
overlap = list(set(P) & set(Q))
overlap = sorted(overlap, key=lambda k: P[k], reverse=True)[:1000]

plt.figure(figsize=(7,4))
plt.scatter([P[k] for k in overlap], [Q[k] for k in overlap])
plt.xscale("log"); plt.yscale("log")
plt.xlabel("MrBayes mass (log)")
plt.ylabel("Model mass (log)")
plt.title("Overlap Topologies: Masses")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 10
#       8 plt.ylabel("Model mass (log)")
#       9 plt.title("Overlap Topologies: Masses")
# ---> 10 plt.tight_layout()
#      11 plt.show()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/pyplot.py:2312, in tight_layout(pad, h_pad, w_pad, rect)
#    2310 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2311 def tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None):
# -> 2312     return gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/figure.py:3236, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3234 renderer = get_renderer(self)
#    3235 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 3236     kwargs = get_tight_layout_figure(
#    3237         self, self.axes, subplotspec_list, renderer,
#    3238         pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    3239 if kwargs:
#    3240     self.subplots_adjust(**kwargs)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/tight_layout.py:320, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     315         return {}
#     316     span_pairs.append((
#     317         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     318         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 320 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     321                                   shape=(max_nrows, max_ncols),
#     322                                   span_pairs=span_pairs,
#     323                                   subplot_list=subplot_list,
#     324                                   ax_bbox_list=ax_bbox_list,
#     325                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     327 # kwargs can be none if tight_layout fails...
#     328 if rect is not None and kwargs is not None:
#     329     # if rect is given, the whole subplots area (including
#     330     # labels) will fit into the rect instead of the
#    (...)
#     334     # auto_adjust_subplotpars twice, where the second run
#     335     # with adjusted rect parameters.
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 if ax.get_visible():
#      81     try:
# ---> 82         bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      83     except TypeError:
#      84         bb += [ax.get_tightbbox(renderer)]
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axes/_base.py:4637, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4635 if self.yaxis.get_visible():
#    4636     try:
# -> 4637         bb_yaxis = self.yaxis.get_tightbbox(
#    4638             renderer, for_layout_only=for_layout_only)
#    4639     except TypeError:
#    4640         # in case downstream library has redefined axis:
#    4641         bb_yaxis = self.yaxis.get_tightbbox(renderer)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1103, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1100 if not self.get_visible():
#    1101     return
# -> 1103 ticks_to_draw = self._update_ticks()
#    1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1045, in Axis._update_ticks(self)
#    1040 def _update_ticks(self):
#    1041     """
#    1042     Update ticks (position and labels) using the current data interval of
#    1043     the axes.  Return the list of ticks that will be drawn.
#    1044     """
# -> 1045     major_locs = self.get_majorticklocs()
#    1046     major_labels = self.major.formatter.format_ticks(major_locs)
#    1047     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2293, in LogLocator.__call__(self)
#    2291 """Return the locations of the ticks."""
#    2292 vmin, vmax = self.axis.get_view_interval()
# -> 2293 return self.tick_values(vmin, vmax)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2318, in LogLocator.tick_values(self, vmin, vmax)
#    2315         vmin = self.axis.get_minpos()
#    2317     if vmin <= 0.0 or not np.isfinite(vmin):
# -> 2318         raise ValueError(
#    2319             "Data has no positive values, and therefore can not be "
#    2320             "log-scaled.")
#    2322 _log.debug('vmin %s vmax %s', vmin, vmax)
#    2324 if vmax < vmin:
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f193c207010> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/pyplot.py:137, in install_repl_displayhook.<locals>.post_execute()
#     135 def post_execute():
#     136     if matplotlib.is_interactive():
# --> 137         draw_all()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:141, in Gcf.draw_all(cls, force)
#     139 for manager in cls.get_all_fig_managers():
#     140     if force or manager.canvas.figure.stale:
# --> 141         manager.canvas.draw_idle()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/backend_bases.py:2060, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2058 if not self._is_idle_drawing:
#    2059     with self._idle_draw_cntx():
# -> 2060         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1045, in Axis._update_ticks(self)
#    1040 def _update_ticks(self):
#    1041     """
#    1042     Update ticks (position and labels) using the current data interval of
#    1043     the axes.  Return the list of ticks that will be drawn.
#    1044     """
# -> 1045     major_locs = self.get_majorticklocs()
#    1046     major_labels = self.major.formatter.format_ticks(major_locs)
#    1047     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2293, in LogLocator.__call__(self)
#    2291 """Return the locations of the ticks."""
#    2292 vmin, vmax = self.axis.get_view_interval()
# -> 2293 return self.tick_values(vmin, vmax)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2318, in LogLocator.tick_values(self, vmin, vmax)
#    2315         vmin = self.axis.get_minpos()
#    2317     if vmin <= 0.0 or not np.isfinite(vmin):
# -> 2318         raise ValueError(
#    2319             "Data has no positive values, and therefore can not be "
#    2320             "log-scaled.")
#    2322 _log.debug('vmin %s vmax %s', vmin, vmax)
#    2324 if vmax < vmin:
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1045, in Axis._update_ticks(self)
#    1040 def _update_ticks(self):
#    1041     """
#    1042     Update ticks (position and labels) using the current data interval of
#    1043     the axes.  Return the list of ticks that will be drawn.
#    1044     """
# -> 1045     major_locs = self.get_majorticklocs()
#    1046     major_labels = self.major.formatter.format_ticks(major_locs)
#    1047     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2293, in LogLocator.__call__(self)
#    2291 """Return the locations of the ticks."""
#    2292 vmin, vmax = self.axis.get_view_interval()
# -> 2293 return self.tick_values(vmin, vmax)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/matplotlib/ticker.py:2318, in LogLocator.tick_values(self, vmin, vmax)
#    2315         vmin = self.axis.get_minpos()
#    2317     if vmin <= 0.0 or not np.isfinite(vmin):
# -> 2318         raise ValueError(
#    2319             "Data has no positive values, and therefore can not be "
#    2320             "log-scaled.")
#    2322 _log.debug('vmin %s vmax %s', vmin, vmax)
#    2324 if vmax < vmin:
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.

# %%
import math
from collections import defaultdict, Counter
import dendropy

# ---------- paths ----------
trprobs_path = "data/DS1.trprobs"
sampled_path = "results_converge_elbo/run_20260219_001447_ntaxa27/sampled_trees.nwk"  # or .nex

# ---------- helpers ----------
def canon_label(x: str) -> str:
    return x.strip().strip("'\"").replace(" ", "_")

def relabel_tree_inplace(tree):
    for nd in tree.leaf_node_iter():
        if nd.taxon is not None and nd.taxon.label is not None:
            nd.taxon.label = canon_label(nd.taxon.label)

def topology_key_unrooted(tree):
    tree.is_rooted = False
    tree.encode_bipartitions()
    full_mask = tree.taxon_namespace.all_taxa_bitmask()
    splits = []
    for b in tree.bipartition_encoding:
        if b.is_trivial():
            continue
        x = b.split_bitmask
        x = min(x, full_mask ^ x)   # canonical orientation
        splits.append(x)
    return tuple(sorted(splits))

def normalize(d):
    s = sum(d.values())
    return {k: v/s for k, v in d.items()} if s > 0 else {}

# ---------- load trees with shared namespace ----------
taxa = dendropy.TaxonNamespace()

mb = dendropy.TreeList.get(
    path=trprobs_path, schema="nexus", taxon_namespace=taxa, preserve_underscores=True
)

# if your sampled file is Newick (one tree per line):
model = dendropy.TreeList.get(
    path=sampled_path, schema="newick", taxon_namespace=taxa, preserve_underscores=True
)
# if it's nexus, use schema="nexus"

for t in mb:
    relabel_tree_inplace(t)
for t in model:
    relabel_tree_inplace(t)

# ---------- P_MB from weights ----------
p_counts = defaultdict(float)
for t in mb:
    w = float(t.weight) if getattr(t, "weight", None) is not None else 1.0
    p_counts[topology_key_unrooted(t)] += w
P = normalize(p_counts)

# ---------- Q_model from frequencies ----------
q_counts = Counter(topology_key_unrooted(t) for t in model)
Nq = sum(q_counts.values())

# ---------- KL(P||Q) with smoothing on MB support ----------
eps = 1e-10
den = Nq + eps * len(P)

kl = 0.0
for topo, p in P.items():
    q = (q_counts.get(topo, 0) + eps) / den
    kl += p * (math.log(p) - math.log(q))

# diagnostics
overlap = sum(1 for k in P if k in q_counts)
overlap_mass = sum(P[k] for k in P if k in q_counts)

print("MB unique topologies:", len(P))
print("Model unique topologies:", len(q_counts))
print("Support overlap:", overlap)
print("P_MB mass on overlap:", overlap_mass)
print("KL(P_MB || Q_model):", kl)
# Out:
# MB unique topologies: 1209
# Model unique topologies: 657
# Support overlap: 0
# P_MB mass on overlap: 0
# KL(P_MB || Q_model): 22.836057358428366

# %%
import math
from collections import Counter
import numpy as np
import dendropy
from dendropy.calculate import treecompare

# ---------- paths ----------
trprobs_path = "data/DS1.trprobs"
sampled_path = "results_converge_elbo/run_20260222_115429_ntaxa27/sampled_trees.nwk"  # change if needed

# ---------- helpers ----------
def canon_label(x: str) -> str:
    return x.strip().strip("'\"").replace(" ", "_")

def relabel_tree_inplace(tree):
    for nd in tree.leaf_node_iter():
        if nd.taxon is not None and nd.taxon.label is not None:
            nd.taxon.label = canon_label(nd.taxon.label)

def leaf_set(tree):
    return {nd.taxon.label for nd in tree.leaf_node_iter() if nd.taxon is not None}

def topology_key_unrooted(tree):
    tree.is_rooted = False
    tree.encode_bipartitions()
    full_mask = tree.taxon_namespace.all_taxa_bitmask()
    splits = []
    for b in tree.bipartition_encoding:
        if b.is_trivial():
            continue
        x = b.split_bitmask
        x = min(x, full_mask ^ x)
        splits.append(x)
    return tuple(sorted(splits))

# ---------- load ----------
taxa = dendropy.TaxonNamespace()

mb = dendropy.TreeList.get(
    path=trprobs_path,
    schema="nexus",
    taxon_namespace=taxa,
    preserve_underscores=True,
)

# If sampled is nexus, change schema="nexus"
sampled = dendropy.TreeList.get(
    path=sampled_path,
    schema="newick",
    taxon_namespace=taxa,
    preserve_underscores=True,
)

for t in mb:
    t.is_rooted = False
    relabel_tree_inplace(t)

for t in sampled:
    t.is_rooted = False
    relabel_tree_inplace(t)

# ---------- sanity: taxa ----------
mb_leaves = leaf_set(mb[0])
sp_leaves = leaf_set(sampled[0])
shared = mb_leaves & sp_leaves

print("MB leaves:", len(mb_leaves))
print("Sampled leaves:", len(sp_leaves))
print("Shared leaves:", len(shared))
print("Only MB:", sorted(mb_leaves - sp_leaves)[:10], "..." if len(mb_leaves - sp_leaves) > 10 else "")
print("Only sampled:", sorted(sp_leaves - mb_leaves)[:10], "..." if len(sp_leaves - mb_leaves) > 10 else "")

if mb_leaves != sp_leaves:
    raise ValueError("Leaf sets differ. RF/KL comparisons are not valid until labels match exactly.")

# ---------- exact topology overlap ----------
mb_keys = Counter(topology_key_unrooted(t) for t in mb)
sp_keys = Counter(topology_key_unrooted(t) for t in sampled)
overlap = set(mb_keys) & set(sp_keys)

print("\nMB unique topologies:", len(mb_keys))
print("Sampled unique topologies:", len(sp_keys))
print("Exact topology overlap count:", len(overlap))

# ---------- nearest-neighbor RF ----------
# Encode once for speed
for t in mb:
    t.encode_bipartitions()
for t in sampled:
    t.encode_bipartitions()

rf_min = []
argmin_idx = []
for i, s in enumerate(sampled):
    best = None
    best_j = None
    for j, m in enumerate(mb):
        d = treecompare.symmetric_difference(s, m)
        if best is None or d < best:
            best = d
            best_j = j
    rf_min.append(best)
    argmin_idx.append(best_j)

rf_min = np.array(rf_min, dtype=float)
n_taxa = len(mb_leaves)
max_rf = 2 * (n_taxa - 3)

print("\nNum sampled trees:", len(sampled))
print("RF min-to-MB mean:", rf_min.mean())
print("RF min-to-MB median:", np.median(rf_min))
print("RF min-to-MB min/max:", rf_min.min(), rf_min.max())
print("Normalized RF mean:", rf_min.mean() / max_rf)

# ---------- optional histogram ----------
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.hist(rf_min, bins=int(rf_min.max()-rf_min.min()+1), edgecolor="black")
plt.xlabel("min RF to MB set")
plt.ylabel("count")
plt.title("Nearest-neighbor RF from sampled trees to MrBayes trees")
plt.tight_layout()
plt.show()

# ---------- optional: print a few closest trees ----------
closest_idx = np.argsort(rf_min)[:10]
print("\nTop 10 closest sampled trees:")
for rank, i in enumerate(closest_idx, 1):
    print(f"{rank:2d}. sampled_idx={i}, min_RF={rf_min[i]:.0f}, matched_MB_idx={argmin_idx[i]}")
# Out:
# MB leaves: 27
# Sampled leaves: 27
# Shared leaves: 27
# Only MB: []
# Only sampled: []
#
# MB unique topologies: 1209
# Sampled unique topologies: 33
# Exact topology overlap count: 20
#
# Num sampled trees: 1000
# RF min-to-MB mean: 0.08
# RF min-to-MB median: 0.0
# RF min-to-MB min/max: 0.0 6.0
# Normalized RF mean: 0.0016666666666666668
# Top 10 closest sampled trees:
#  1. sampled_idx=0, min_RF=0, matched_MB_idx=1
#  2. sampled_idx=649, min_RF=0, matched_MB_idx=5
#  3. sampled_idx=650, min_RF=0, matched_MB_idx=38
#  4. sampled_idx=651, min_RF=0, matched_MB_idx=5
#  5. sampled_idx=652, min_RF=0, matched_MB_idx=1
#  6. sampled_idx=653, min_RF=0, matched_MB_idx=5
#  7. sampled_idx=654, min_RF=0, matched_MB_idx=1
#  8. sampled_idx=655, min_RF=0, matched_MB_idx=5
#  9. sampled_idx=656, min_RF=0, matched_MB_idx=1
# 10. sampled_idx=657, min_RF=0, matched_MB_idx=1

# %%
from Bio import SeqIO

records = SeqIO.parse("data/seq_gen_1000_toy_data_5_reordered.fasta", "fasta")
count = SeqIO.write(records, "data/seq_gen_1000_toy_data_5_reordered.nexus", "nexus")
print("Converted %i records" % count)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from Bio import SeqIO
#       3 records = SeqIO.parse("data/seq_gen_1000_DS1_reordered.fasta", "fasta")
# ----> 4 count = SeqIO.write(records, "data/seq_gen_1000_DS1_reordered.nexus", "nexus")
#       5 print("Converted %i records" % count)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/Bio/SeqIO/__init__.py:558, in write(sequences, handle, format)
#     555 from Bio.Align import MultipleSeqAlignment
#     557 alignment = MultipleSeqAlignment(sequences)
# --> 558 alignment_count = AlignIO.write([alignment], handle, format)
#     559 if alignment_count != 1:
#     560     raise RuntimeError(
#     561         "Internal error - the underlying writer "
#     562         "should have returned 1, not %r" % alignment_count
#     563     )
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/Bio/AlignIO/__init__.py:215, in write(alignments, handle, format)
#     213 if format in _FormatToWriter:
#     214     writer_class = _FormatToWriter[format]
# --> 215     count = writer_class(fp).write_file(alignments)
#     216 elif format in SeqIO._FormatToWriter:
#     217     # Exploit the existing SeqIO parser to do the dirty work!
#     218     # TODO - Can we make one call to SeqIO.write() and count the alignments?
#     219     count = 0
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/Bio/AlignIO/NexusIO.py:116, in NexusWriter.write_file(self, alignments)
#     113     pass
#     115 # Good.  Actually write the single alignment,
# --> 116 self.write_alignment(alignment)
#     117 return 1
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/Bio/AlignIO/NexusIO.py:132, in NexusWriter.write_alignment(self, alignment, interleave)
#     130 if columns == 0:
#     131     raise ValueError("Non-empty sequences are required")
# --> 132 datatype = self._classify_mol_type_for_nexus(alignment)
#     133 minimal_record = (
#     134     "#NEXUS\nbegin data; dimensions ntax=0 nchar=0; format datatype=%s; end;"
#     135     % datatype
#     136 )
#     137 n = Nexus.Nexus(minimal_record)
#
# File ~/miniconda3/envs/phylovae/lib/python3.10/site-packages/Bio/AlignIO/NexusIO.py:167, in NexusWriter._classify_mol_type_for_nexus(self, alignment)
#     165     return "protein"
#     166 else:
# --> 167     raise ValueError("Need the molecule type to be defined")
#
# ValueError: Need the molecule type to be defined

# %%
from Bio import SeqIO

input_file = "data/seq_gen_1000_toy_data_5_reordered.fasta"
output_file = "data/seq_gen_1000_toy_data_5_reordered.nexus"

# 1. Parse the FASTA file
records = list(SeqIO.parse(input_file, "fasta"))

# 2. Tell Biopython that these sequences are DNA
for record in records:
    record.annotations["molecule_type"] = "DNA"

# 3. Write them to the NEXUS file
count = SeqIO.write(records, output_file, "nexus")
print(f"Converted {count} records to NEXUS format.")

# 4. Append the MrBayes command block automatically
mrbayes_block = """
BEGIN MRBAYES;
    [Set Jukes-Cantor model]
    lset nst=1 basefreq=equal;
    
    [Run MCMC]
    mcmc ngen=100000 samplefreq=100 printfreq=1000 diagnfreq=10000 file=mb_posterior;
    
    [Summarize trees and parameters, discarding 25% burn-in]
    sumt burnin=250;
    sump burnin=250;
    
    quit;
END;
"""

with open(output_file, "a") as f:
    f.write(mrbayes_block)

print("Successfully appended MrBayes execution block!")
# Out:
# Converted 5 records to NEXUS format.
# Successfully appended MrBayes execution block!
